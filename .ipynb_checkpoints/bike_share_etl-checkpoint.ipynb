# %%
import pandas as pd
from sqlalchemy import create_engine
from config import password
import pymysql
pymysql.install_as_MySQLdb()

# %%
weather_file = "Resources/weather.csv"
weather_df = pd.read_csv(weather_file)
weather_df.head()
# Out:
#          Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0  10/13/2014                 71                62.0                54
# 1  10/14/2014                 63                59.0                55
# 2  10/15/2014                 62                58.0                54
# 3  10/16/2014                 71                61.0                52
# 4  10/17/2014                 64                60.0                57
#
#    Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# 0               55               51              46            87
# 1               52               51              50            88
# 2               53               50              46            87
# 3               49               46              42            83
# 4               55               51              41            87
#
#    Mean_Humidity  Min_Humidity   ...    Mean_Sea_Level_Pressure_In  \
# 0             68            46   ...                         29.79
# ...

# %%
weather_clean_df = weather_df[['Date', 'Max_Temperature_F','Mean_Temperature_F','Min_TemperatureF','Max_Humidity','Mean_Humidity','Min_Humidity',
                               'Max_Wind_Speed_MPH','Mean_Wind_Speed_MPH','Max_Gust_Speed_MPH','Events']]
weather_clean_df.head()
# Out:
#          Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0  10/13/2014                 71                62.0                54
# 1  10/14/2014                 63                59.0                55
# 2  10/15/2014                 62                58.0                54
# 3  10/16/2014                 71                61.0                52
# 4  10/17/2014                 64                60.0                57
#
#    Max_Humidity  Mean_Humidity  Min_Humidity  Max_Wind_Speed_MPH  \
# 0            87             68            46                  13
# 1            88             78            63                  10
# 2            87             77            67                  18
# 3            83             61            36                   9
# 4            87             72            46                   8
#
#    Mean_Wind_Speed_MPH Max_Gust_Speed_MPH Events
# 0                    4                 21   Rain
# ...

# %%
trip_file = "Resources/trip.csv"
trip_df = pd.read_csv(trip_file,error_bad_lines=False)
trip_df.head()
# Out:
# b'Skipping line 50794: expected 12 fields, saw 20\n'
#    trip_id         starttime          stoptime    bikeid  tripduration  \
# 0      431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1      432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2      433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3      434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4      435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
#
#      from_station_name                                    to_station_name  \
# 0  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 1  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 2  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 3  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 4  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
#
# ...

# %%
station_file = "Resources/station.csv"
station_df = pd.read_csv(station_file)
station_df.head()
# Out:
#   station_id                    name        lat        long install_date  \
# 0      BT-01      3rd Ave & Broad St  47.618418 -122.350964   10/13/2014
# 1      BT-03       2nd Ave & Vine St  47.615829 -122.348564   10/13/2014
# 2      BT-04  6th Ave & Blanchard St  47.616094 -122.341102   10/13/2014
# 3      BT-05  2nd Ave & Blanchard St  47.613110 -122.344208   10/13/2014
# 4     CBD-03      7th Ave & Union St  47.610731 -122.332447   10/13/2014
#
#    install_dockcount modification_date  current_dockcount decommission_date
# 0                 18               NaN                 18               NaN
# 1                 16               NaN                 16               NaN
# 2                 16               NaN                 16               NaN
# 3                 14               NaN                 14               NaN
# 4                 20               NaN                 20               NaN

# %%
connection_string = "root:{password}@Local Host/bikeshare_db"
engine = create_engine(f'mysql://{connection_string}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     581                                 (self.host, self.port), self.connect_timeout,
# --> 582                                 **kwargs)
#     583                             break
#
# ~\Anaconda3\envs\PythonData\lib\socket.py in create_connection(address, timeout, source_address)
#     703     err = None
# --> 704     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     705         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\envs\PythonData\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# ...
